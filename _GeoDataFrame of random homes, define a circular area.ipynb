# %%
import folium
from folium import GeoJson

# Create a folium map centered at the circle center
m = folium.Map(location=[circle_center.y, circle_center.x], zoom_start=12)

# Add home locations to the map
for idx, row in home_gdf.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=f"Home {row['home_id']}").add_to(m)

# Add the circular area to the map
folium.GeoJson(circle_polygon.__geo_interface__, style_function=lambda x: {'color': 'red'}).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from weasyprint import HTML

# Function to save a Folium map as a PDF using weasyprint
def save_folium_map_as_pdf(map_object, output_path='map_output.pdf'):
    # Create a temporary HTML file
    tmp_html = 'temp_map.html'
    map_object.save(tmp_html)

    # Use weasyprint to convert the HTML to PDF
    HTML(tmp_html).write_pdf(output_path)

    # Delete the temporary HTML file
    # !del {tmp_html}  # Use 'del' instead of 'rm' for Windows

# Create a Folium map
m = folium.Map(location=[40.75, -74.05], zoom_start=12)

# Add home locations to the map
for idx, row in home_gdf.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=f"Home {row['home_id']}").add_to(m)

# Add the circular area to the map
folium.GeoJson(circle_polygon.__geo_interface__, style_function=lambda x: {'color': 'red'}).add_to(m)

# Save the map as a PDF directly to the specified local path
save_folium_map_as_pdf(m, r'C:\Users\Administrator\Desktop\samplework\map_output.pdf')
# Out:
# -----
#
# WeasyPrint could not import some external libraries. Please carefully follow the installation steps before reporting an issue:
# https://doc.courtbouillon.org/weasyprint/stable/first_steps.html#installation
# https://doc.courtbouillon.org/weasyprint/stable/first_steps.html#troubleshooting
#
# -----
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 2
#       1 import folium
# ----> 2 from weasyprint import HTML
#       4 # Function to save a Folium map as a PDF using weasyprint
#       5 def save_folium_map_as_pdf(map_object, output_path='map_output.pdf'):
#       6     # Create a temporary HTML file
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\weasyprint\__init__.py:387
#     384         yield 'string', string, base_url, None
#     386 # Work around circular imports.
# ...

# %%
import folium
from weasyprint import HTML

# Function to save a Folium map as a PDF using weasyprint
def save_folium_map_as_pdf(map_object, output_path='map_output.pdf'):
    # Create a temporary HTML file
    tmp_html = 'temp_map.html'
    map_object.save(tmp_html)

    # Use weasyprint to convert the HTML to PDF
    HTML(string=open(tmp_html, 'rb').read()).write_pdf(output_path)

    # Delete the temporary HTML file
    # !del {tmp_html}  # Use 'del' instead of 'rm' for Windows

# Create a Folium map
m = folium.Map(location=[40.75, -74.05], zoom_start=12)

# Add home locations to the map
for idx, row in home_gdf.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=f"Home {row['home_id']}").add_to(m)

# Add the circular area to the map
folium.GeoJson(circle_polygon.__geo_interface__, style_function=lambda x: {'color': 'red'}).add_to(m)

# Save the map as a PDF directly to the specified local path
save_folium_map_as_pdf(m, r'C:\Users\Administrator\Desktop\samplework\map_output.pdf')
# Out:
# -----
#
# WeasyPrint could not import some external libraries. Please carefully follow the installation steps before reporting an issue:
# https://doc.courtbouillon.org/weasyprint/stable/first_steps.html#installation
# https://doc.courtbouillon.org/weasyprint/stable/first_steps.html#troubleshooting
#
# -----
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 2
#       1 import folium
# ----> 2 from weasyprint import HTML
#       4 # Function to save a Folium map as a PDF using weasyprint
#       5 def save_folium_map_as_pdf(map_object, output_path='map_output.pdf'):
#       6     # Create a temporary HTML file
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\weasyprint\__init__.py:387
#     384         yield 'string', string, base_url, None
#     386 # Work around circular imports.
# ...
